# %% [markdown]
# # Process Data

# %%
import pandas as pd

# %%
leaders = pd.read_excel('datain/scrap_leaders.xlsx')
leaders.head()
# Out:
#    SL First Name         Last Name  \
# 0   1      Vitor          Cambraia
# 1   2     Xavier    Perez Toledano
# 2   3     Victor  Pedraza Gonzalez
# 3   4      Pedro  Moreno Cantalejo
# 4   5      Angel             Acuna
#
#                                                  Bio  \
# 0                          Fundador na Café Tramonti
# 1                                      CEO at Bilden
# 2                   Socio Fundador y CIO en CREDIMON
# 3              Founder & C.E.O en Hill House Capital
# 4  CEO en IPIA | Liderazgo en Estrategia, Expansi...
#
#                    Contact Email  \
# 0  vcambraia@cafetramonti.com.br
# 1           xperez@bilden.com.mx
# 2    victor.pedraza@credimon.com
# 3  pedro.moreno@hillhouse.com.mx
# 4      angel.zamora@ipiam.edu.mx
#
#                                  Person Linkedin Url            Industry  \
# 0           http://www.linkedin.com/in/vitorcambraia    food & beverages
# ...
